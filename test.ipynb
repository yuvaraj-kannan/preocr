# %%
from preocr import extract_native_data

# %%
extract_native_data("/home/yuvarajk/Downloads/kushali.pdf",pages=[1], markdown_clean=True, markdown_structured=True, output_format="markdown")
# Out:
# {'complete': '**Name** KHUSHALI PAREKH\n**Age/Gender** 25 Years/Female\n\n00000012356791\n\n**Referred By** SELF\n**Client Name** PATEL CLINICAL LABORATORY,\nVAPI\n\n**Collection Date** 06-09-2025 17:14:00\n**Report Release Date** 07-09-2025 16:56:02\n\n## Healthy Hearty NCR-Delhi\n\n| No. | Investigation | Observed Value | Unit | Biological Ref. Interval |\n| --- | --- | --- | --- | --- |\n| 1 | Total RBC | 4.65 | 10^6/µL | 4.1-5.1 |\n| 2 | Hemoglobin | 12.8 | g/dL | 12.3-15.3 |\n| 3 | Hematocrit (PCV) | 40.9 | % | 33-57 |\n| 4 | Mean Corpuscular Volume (MCV) | 87.9 | fL | 80-96 |\n| 5 | Mean Corpuscular Hemoglobin (MCH) | 27.5 | pg | 27.5-33.2 |\n| 6 | Mean Corpuscular Hemoglobin Concentration (MCHC) | 31.3 | g/dL | 29.4- 34.5 |\n| 7 | Red Cell Distribution Width (RDW-CV) | 15.3 | % | 12-15 |\n| 8 | Red Cell Distribution Width-SD(RDW-SD) | 49.3 | fl | 32-60.4 |\n| 9 | Nucleated Red Blood Cells | 0.0 | cells/µL | 0 - 1.36 |\n| 10 | Nucleated Red Blood Cells Percentage | 0.0 | % | 0-
# ...
